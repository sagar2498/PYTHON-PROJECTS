# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('customer_details.csv')
col=['Id','Gender','Age','Driving licence Active','Region code','Previously Insured','Vehical Age','Vehical Damage']
df.columns=col
df.head()
# Out:
#     Id  Gender   Age  Driving licence Active  Region code  Previously Insured  \
# 0  1.0    Male  44.0                     1.0         28.0                 0.0
# 1  2.0    Male  76.0                     1.0          3.0                 0.0
# 2  3.0    Male  47.0                     1.0         28.0                 0.0
# 3  4.0    Male  21.0                     1.0         11.0                 1.0
# 4  5.0  Female  29.0                     1.0         41.0                 1.0
#
#   Vehical Age Vehical Damage
# 0   > 2 Years            Yes
# 1    1-2 Year             No
# 2   > 2 Years            Yes
# 3    < 1 Year             No
# 4    < 1 Year             No

# %%
df1_n = df1.isnull()
for i in df1_n.columns.values.tolist():
    print(i)
    print(df1_n[i].value_counts())
    print('')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7432\347389810.py in <module>
# ----> 1 df1_n = df1.isnull()
#       2 for i in df1_n.columns.values.tolist():
#       3     print(i)
#       4     print(df1_n[i].value_counts())
#       5     print('')
#
# NameError: name 'df1' is not defined

# %%
df.dropna(subset=['Id'],axis=0,inplace=True)
df.reset_index(drop=True,inplace=True)
df['Age'].fillna(df['Age'].mean(),inplace=True)
df1['Age'].fillna(df1['Age'].mean(),inplace = True)
df.head()
# Out:
#     Id  Gender   Age  Driving licence Active  Region code  Previously Insured  \
# 0  1.0    Male  44.0                     1.0         28.0                 0.0
# 1  2.0    Male  76.0                     1.0          3.0                 0.0
# 2  3.0    Male  47.0                     1.0         28.0                 0.0
# 3  4.0    Male  21.0                     1.0         11.0                 1.0
# 4  5.0  Female  29.0                     1.0         41.0                 1.0
#
#   Vehical Age Vehical Damage
# 0   > 2 Years            Yes
# 1    1-2 Year             No
# 2   > 2 Years            Yes
# 3    < 1 Year             No
# 4    < 1 Year             No

# %%
df.dropna(subset=['Id'],axis=0,inplace=True)
df.reset_index(drop=True,inplace=True)
df['Age'].fillna(df['Age'].mean(),inplace=True)
df.head()
# Out:
#     Id  Gender   Age  Driving licence Active  Region code  Previously Insured  \
# 0  1.0    Male  44.0                     1.0         28.0                 0.0
# 1  2.0    Male  76.0                     1.0          3.0                 0.0
# 2  3.0    Male  47.0                     1.0         28.0                 0.0
# 3  4.0    Male  21.0                     1.0         11.0                 1.0
# 4  5.0  Female  29.0                     1.0         41.0                 1.0
#
#   Vehical Age Vehical Damage
# 0   > 2 Years            Yes
# 1    1-2 Year             No
# 2   > 2 Years            Yes
# 3    < 1 Year             No
# 4    < 1 Year             No

# %%
df.dropna(subset=['Id'],axis=0,inplace=True)
df.reset_index(drop=True,inplace=True)
df['Age'].fillna(df['Age'].mean(),inplace=True)
df.head()
# Out:
#     Id  Gender   Age  Driving licence Active  Region code  Previously Insured  \
# 0  1.0    Male  44.0                     1.0         28.0                 0.0
# 1  2.0    Male  76.0                     1.0          3.0                 0.0
# 2  3.0    Male  47.0                     1.0         28.0                 0.0
# 3  4.0    Male  21.0                     1.0         11.0                 1.0
# 4  5.0  Female  29.0                     1.0         41.0                 1.0
#
#   Vehical Age Vehical Damage
# 0   > 2 Years            Yes
# 1    1-2 Year             No
# 2   > 2 Years            Yes
# 3    < 1 Year             No
# 4    < 1 Year             No

# %%
def plot_boxplot(df,ft):
    df.boxplot(column=[ft])
    plt.grid(False)
    plt.show()
plot_boxplot(df,'Age')

# %%
def plot_boxplot(df,ft):
    df.boxplot(column=[ft])
    plt.grid(False)
    plt.show

plot_boxplot(df,'Age')

# %%
str1="sagar is a good person"
print('UPPERCASE :',str1.upper())
str2=str1
print('lowercase:',str2.lower())
str3=str2
print('Title :',str3.title())
print('Split :',str3.split('o'))
# Out:
# UPPERCASE : SAGAR IS A GOOD PERSON
# lowercase: sagar is a good person
# Title : Sagar Is A Good Person
# Split : ['sagar is a g', '', 'd pers', 'n']
