# %% [markdown]
# # INDIAN FOOD ANALYSIS

# %% [markdown]
# ![pie_icon.ico](attachment:pie_icon.ico)

# %% [markdown]
# ## importing modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
colors = ["#54436B", "#50CB93", "#ED8E7C", "#FFD523", '#00C1D4', '#F8485E']

# Set your custom color palette
sns.set_palette(sns.color_palette(colors))

# %% [markdown]
# ## * Initial Data Exploration

# %%
df=pd.read_csv('indian_food.csv')
df
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %% [markdown]
# #### Capitalizing headres

# %%
df.columns=df.columns.str.capitalize()
df
# Out:
#                Name                                        Ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            Diet  Prep_time  Cook_time Flavor_profile   Course  \
# ...

# %% [markdown]
# #### Reading data

# %%
df.head(10)
# Out:
#              Name                                        Ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 5          Imarti                          Sugar syrup, lentil flour
# 6          Jalebi  Maida, corn flour, baking soda, vinegar, curd,...
# 7      Kaju katli                     Cashews, ghee, cardamom, sugar
# 8        Kalakand                        Milk, cottage cheese, sugar
# 9           Kheer                    Milk, rice, sugar, dried fruits
#
#          Diet  Prep_time  Cook_time Flavor_profile   Course          State  \
# 0  vegetarian         45         25          sweet  dessert    West Bengal
# ...

# %%
df.tail(10)
# Out:
#                   Name                                        Ingredients  \
# 245         Pani Pitha  Tea leaves, white sesame seeds, dry coconut, s...
# 246             Payokh  Basmati rice, rose water, sugar, clarified but...
# 247  Prawn malai curry      Coconut milk, prawns, garlic, turmeric, sugar
# 248           Red Rice  Red pepper, red onion, butter, watercress, oli...
# 249             Shukto  Green beans, bitter gourd, ridge gourd, banana...
# 250          Til Pitha            Glutinous rice, black sesame seeds, gur
# 251            Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252             Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253          Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254             Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#                Diet  Prep_time  Cook_time Flavor_profile       Course  \
# 245      vegetarian         10         20             -1  main course
# ...

# %%
df.shape
# Out:
# (255, 9)

# %% [markdown]
# ## Cleaning Data

# %%
pd.isnull(df)
# Out:
#       Name  Ingredients   Diet  Prep_time  Cook_time  Flavor_profile  Course  \
# 0    False        False  False      False      False           False   False
# 1    False        False  False      False      False           False   False
# 2    False        False  False      False      False           False   False
# 3    False        False  False      False      False           False   False
# 4    False        False  False      False      False           False   False
# ..     ...          ...    ...        ...        ...             ...     ...
# 250  False        False  False      False      False           False   False
# 251  False        False  False      False      False           False   False
# 252  False        False  False      False      False           False   False
# 253  False        False  False      False      False           False   False
# 254  False        False  False      False      False           False   False
#
#      State  Region
# 0    False   False
# ...

# %%
pd.notnull(df)
# Out:
#      Name  Ingredients  Diet  Prep_time  Cook_time  Flavor_profile  Course  \
# 0    True         True  True       True       True            True    True
# 1    True         True  True       True       True            True    True
# 2    True         True  True       True       True            True    True
# 3    True         True  True       True       True            True    True
# 4    True         True  True       True       True            True    True
# ..    ...          ...   ...        ...        ...             ...     ...
# 250  True         True  True       True       True            True    True
# 251  True         True  True       True       True            True    True
# 252  True         True  True       True       True            True    True
# 253  True         True  True       True       True            True    True
# 254  True         True  True       True       True            True    True
#
#      State  Region
# 0     True    True
# 1     True    True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            255 non-null    object
#  1   Ingredients     255 non-null    object
#  2   Diet            255 non-null    object
#  3   Prep_time       255 non-null    int64
#  4   Cook_time       255 non-null    int64
#  5   Flavor_profile  255 non-null    object
#  6   Course          255 non-null    object
#  7   State           255 non-null    object
#  8   Region          254 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 18.1+ KB

# %%
df.describe()
# Out:
#         Prep_time   Cook_time
# count  255.000000  255.000000
# mean    31.105882   34.529412
# std     72.554409   48.265650
# min     -1.000000   -1.000000
# 25%     10.000000   20.000000
# 50%     10.000000   30.000000
# 75%     20.000000   40.000000
# max    500.000000  720.000000

# %%
# Identifying the null value
df[df['Region'].isnull()]
# Out:
#          Name                                        Ingredients        Diet  \
# 110  Panjeeri  Whole wheat flour, musk melon seeds, poppy see...  vegetarian
#
#      Prep_time  Cook_time Flavor_profile   Course          State Region
# 110         10         25          sweet  dessert  Uttar Pradesh    NaN

# %%
# # Correcting the entry and checking if it worked
df['Region'] = df['Region'].replace(np.nan, 'North')
df[df['Region'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Name, Ingredients, Diet, Prep_time, Cook_time, Flavor_profile, Course, State, Region]
# Index: []

# %%
# Replacing weird entries with values that makes more sense
df['Prep_time'] = df['Prep_time'].replace(-1, 0)
df['Cook_time'] = df['Cook_time'].replace(-1, 0)
df['Flavor_profile'] = df['Flavor_profile'].replace('-1', 'others')
df['Region'] = df['Region'].replace('-1', 'Others')
df['State'] = df['State'].replace('-1', 'Others')

print(df['Flavor_profile'].unique())
print(df['Region'].unique())
print(df['State'].unique())
print(df.describe())
# Out:
# ['sweet' 'spicy' 'bitter' 'others' 'sour']
# ['East' 'West' 'North' 'Others' 'North East' 'South' 'Central']
# ['West Bengal' 'Rajasthan' 'Punjab' 'Uttar Pradesh' 'Others' 'Odisha'
#  'Maharashtra' 'Uttarakhand' 'Assam' 'Bihar' 'Andhra Pradesh' 'Karnataka'
#  'Telangana' 'Kerala' 'Tamil Nadu' 'Gujarat' 'Tripura' 'Manipur'
#  'Nagaland' 'NCT of Delhi' 'Jammu & Kashmir' 'Chhattisgarh' 'Haryana'
#  'Madhya Pradesh' 'Goa']
#         Prep_time   Cook_time
# count  255.000000  255.000000
# mean    31.223529   34.639216
# std     72.502844   48.185452
# min      0.000000    0.000000
# 25%     10.000000   20.000000
# 50%     10.000000   30.000000
# 75%     20.000000   40.000000
# max    500.000000  720.000000

# %%
# Turning the ingredients entry into list instead of a single string
ingredients = []

for row in range(len(df)):
    ing = df['Ingredients'][row].replace(" ", "").split(',')
    ingredients.append(ing)
    
df['Ingredients'] = ingredients
df.head()
# Out:
#              Name                                        Ingredients  \
# 0      Balu shahi                   [Maidaflour, yogurt, oil, sugar]
# 1          Boondi                           [Gramflour, ghee, sugar]
# 2  Gajar ka halwa     [Carrots, milk, sugar, ghee, cashews, raisins]
# 3          Ghevar  [Flour, ghee, kewra, milk, clarifiedbutter, su...
# 4     Gulab jamun  [Milkpowder, plainflour, bakingpowder, ghee, m...
#
#          Diet  Prep_time  Cook_time Flavor_profile   Course        State  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   Region
# 0   East
# 1   West
# 2  North
# 3   West
# 4   East

# %% [markdown]
# # Ingredients per Region

# %%
# Lists that will be filled with each ingredient value, repeated or not
East = []
West = []
North = []
Others = []
NorthEast = []
South = []
Central = []

# Filling the lists
for row in range(len(df)):
    if df['Region'][row] == 'East':
        East.extend(df['Ingredients'][row])
    if df['Region'][row] == 'West':
        West.extend(df['Ingredients'][row])
    if df['Region'][row] == 'North':
        North.extend(df['Ingredients'][row])
    if df['Region'][row] == 'North East':
        NorthEast.extend(df['Ingredients'][row])
    if df['Region'][row] == 'South':
        South.extend(df['Ingredients'][row])
    if df['Region'][row] == 'Central':
        Central.extend(df['Ingredients'][row])
    if df['Region'][row] == 'Others':
        Others.extend(df['Ingredients'][row])

# Series witch include each unique ingredient value
all_ing = pd.Series(East+West+North+Others+NorthEast+South+Central).unique()

# Lists that will store the number of times each ingredient appears
EastC = []
WestC = []
NorthC = []
OthersC = []
NorthEC = []
SouthC = []
CentralC = []

# Filling the lists
for ingredient in all_ing:
    EastC.append(East.count(ingredient))
    WestC.append(West.count(ingredient))
    NorthC.append(North.count(ingredient))
    OthersC.append(Others.count(ingredient))
    NorthEC.append(NorthEast.count(ingredient))
    SouthC.append(South.count(ingredient))
    CentralC.append(Central.count(ingredient))

# Creating the dataset with the values collected
ing_per_region = pd.DataFrame({'East': EastC, 'West': WestC, 'North': NorthC, 'Others': OthersC, 'North East': NorthEC,
                               'South': SouthC, 'Central': CentralC}, index=all_ing) 

# Adding a column with the sum of all the other columns
ing_per_region['Sum'] = (ing_per_region['East'] + ing_per_region['West'] + ing_per_region['North'] + ing_per_region['Others'] 
                        + ing_per_region['North East'] + ing_per_region['South'] + ing_per_region['Central'])

ing_per_region.head(15)
# Out:
#                East  West  North  Others  North East  South  Central  Sum
# Maidaflour        1     0      0       0           0      1        0    2
# yogurt            1     1      2       0           0      0        0    4
# oil               2     2      1       0           0      0        0    5
# sugar            14    12      4       5           2      7        0   44
# Milkpowder        1     0      0       0           0      0        1    2
# plainflour        1     2      1       0           0      0        0    4
# bakingpowder      1     0      0       0           1      0        0    2
# ghee              6     6      3       3           0      7        0   25
# milk              2     4      2       0           1      6        0   15
# water             1     0      1       0           1      0        0    3
# rosewater         1     0      0       0           1      0        0    2
# Sugarsyrup        1     0      0       0           0      0        0    1
# ...

# %% [markdown]
# ### *1 States with Number of dishes

# %%
print("STATES WITH NUMBER OF DISHES")
pd.crosstab(df["State"],["Name"])
# Out:
# STATES WITH NUMBER OF DISHES
# col_0            Name
# State
# Andhra Pradesh     10
# Assam              21
# Bihar               3
# Chhattisgarh        1
# Goa                 3
# Gujarat            35
# Haryana             1
# Jammu & Kashmir     2
# Karnataka           6
# Kerala              8
# Madhya Pradesh      2
# Maharashtra        30
# Manipur             2
# NCT of Delhi        1
# Nagaland            1
# Odisha              7
# Others             24
# Punjab             32
# Rajasthan           6
# Tamil Nadu         20
# Telangana           5
# Tripura             1
# Uttar Pradesh       9
# Uttarakhand         1
# West Bengal        24

# %% [markdown]
# ###  * 2 show top 10  states ,who have highest number of dishes

# %%
print("TOP 10 STATES WITH HIGHEST NUMBER OF DISHES ")
y=df['State'].value_counts().head(10)
print(y)
# Out:
# TOP 10 STATES WITH HIGHEST NUMBER OF DISHES
# Gujarat           35
# Punjab            32
# Maharashtra       30
# West Bengal       24
# Others            24
# Assam             21
# Tamil Nadu        20
# Andhra Pradesh    10
# Uttar Pradesh      9
# Kerala             8
# Name: State, dtype: int64

# %%
print("TOP 10 STATES WITH HIGHEST NUMBER OF DISHES ")
y=df['State'].value_counts().head(10)
print(y)
# Out:
# TOP 10 STATES WITH HIGHEST NUMBER OF DISHES
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4248\1710878688.py in <module>
#       1 print("TOP 10 STATES WITH HIGHEST NUMBER OF DISHES ")
# ----> 2 y=df['State'].value_counts().head(-10)
#       3 print(y)
#
# NameError: name 'df' is not defined

# %%
print("REGIONS WITH NUMBER OF DISHES")
pd.crosstab(df["Region"],["number"])
# Out:
# REGIONS WITH NUMBER OF DISHES
# col_0       number
# Region
# Central          3
# East            31
# North           50
# North East      25
# Others          13
# South           59
# West            74

# %% [markdown]
# ## 3 Show all of sweet dishes from West Bengal

# %%
df[(df['Diet']=='vegetarian')&(df['State']=='West Bengal')&(df['Flavor_profile']=='sweet')]
# Out:
#                    Name                                        Ingredients  \
# 0            Balu shahi                   [Maidaflour, yogurt, oil, sugar]
# 4           Gulab jamun  [Milkpowder, plainflour, bakingpowder, ghee, m...
# 5                Imarti                          [Sugarsyrup, lentilflour]
# 8              Kalakand                       [Milk, cottagecheese, sugar]
# 23            Cham cham  [Flour, cream, sugar, saffron, lemonjuice, coc...
# 25             Ledikeni                              [Chhena, sugar, ghee]
# 28             Mihidana                          [Besanflour, sugar, ghee]
# 29            Misti doi                                    [Milk, jaggery]
# 30               Pantua                       [Chhena, sugar, ghee, flour]
# 33            Ras malai                   [Chhena, reducedmilk, pistachio]
# 34             Rasgulla                          [Chhena, sugar, cardamom]
# ...

# %%
df.shape
# Out:
# (255, 9)

# %% [markdown]
# ## 4 . display only name of all dishes that were reside in karnataka only

# %%
df[(df['Region']=='South')&(df['State']=='Karnataka')]['Name']
# Out:
# 40      Dharwad pedha
# 45         Mysore pak
# 46     Obbattu holige
# 126    Bisi bele bath
# 140         Koshambri
# 157           Sandige
# Name: Name, dtype: object

# %% [markdown]
# # 5. Increase all the values of 'cook_time' column by 5

# %%
print('before increasing value by 5')
df.head()
# Out:
# before increasing value by 5
#              Name                                        Ingredients  \
# 0      Balu shahi                   [Maidaflour, yogurt, oil, sugar]
# 1          Boondi                           [Gramflour, ghee, sugar]
# 2  Gajar ka halwa     [Carrots, milk, sugar, ghee, cashews, raisins]
# 3          Ghevar  [Flour, ghee, kewra, milk, clarifiedbutter, su...
# 4     Gulab jamun  [Milkpowder, plainflour, bakingpowder, ghee, m...
#
#          Diet  Prep_time  Cook_time Flavor_profile   Course        State  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   Region
# 0   East
# 1   West
# 2  North
# 3   West
# 4   East

# %%
print("After increasing time by 5")
df['Cook_time']=df['Cook_time'].apply(lambda x:x+5)

df
# Out:
# After increasing time by 5
#                Name                                        Ingredients  \
# 0        Balu shahi                   [Maidaflour, yogurt, oil, sugar]
# 1            Boondi                           [Gramflour, ghee, sugar]
# 2    Gajar ka halwa     [Carrots, milk, sugar, ghee, cashews, raisins]
# 3            Ghevar  [Flour, ghee, kewra, milk, clarifiedbutter, su...
# 4       Gulab jamun  [Milkpowder, plainflour, bakingpowder, ghee, m...
# ..              ...                                                ...
# 250       Til Pitha             [Glutinousrice, blacksesameseeds, gur]
# 251         Bebinca  [Coconutmilk, eggyolks, clarifiedbutter, allpu...
# 252          Shufta  [Cottagecheese, drydates, driedrosepetals, pis...
# 253       Mawa Bati  [Milkpowder, dryfruits, arrowrootpowder, allpu...
# 254          Pinaca  [Brownrice, fennelseeds, gratedcoconut, blackp...
#
#            Diet  Prep_time  Cook_time Flavor_profile   Course  \
# ...

# %% [markdown]
# ## 6 .Top 10 Shortest Overall Time Meal per Course

# %% [markdown]
# ###### For this analysis I'll be adding a new column to our first dataset that will give us the sum of preparation time and cooking time.

# %%
df['Time'] = df['Prep_time'] + df['Cook_time']
df.head(10)
# Out:
#              Name                                        Ingredients  \
# 0      Balu shahi                   [Maidaflour, yogurt, oil, sugar]
# 1          Boondi                           [Gramflour, ghee, sugar]
# 2  Gajar ka halwa     [Carrots, milk, sugar, ghee, cashews, raisins]
# 3          Ghevar  [Flour, ghee, kewra, milk, clarifiedbutter, su...
# 4     Gulab jamun  [Milkpowder, plainflour, bakingpowder, ghee, m...
# 5          Imarti                          [Sugarsyrup, lentilflour]
# 6          Jalebi  [Maida, cornflour, bakingsoda, vinegar, curd, ...
# 7      Kaju katli                   [Cashews, ghee, cardamom, sugar]
# 8        Kalakand                       [Milk, cottagecheese, sugar]
# 9           Kheer                   [Milk, rice, sugar, driedfruits]
#
#          Diet  Prep_time  Cook_time Flavor_profile   Course          State  \
# 0  vegetarian         45         30          sweet  dessert    West Bengal
# ...

# %% [markdown]
# ## 7.What Ingredients Define the Flavor Profile

# %% [markdown]
# ##### over all Flavor distribution

# %%
plt.figure(figsize=(12,4))
sns.histplot(df['Flavor_profile'])
plt.title('Flavor Profile Distribution')

plt.show()

# %%
type('State')
# Out:
# str

# %%
df = pd.DataFrame(df)
df
# Out:
#                Name                                        Ingredients  \
# 0        Balu shahi                   [Maidaflour, yogurt, oil, sugar]
# 1            Boondi                           [Gramflour, ghee, sugar]
# 2    Gajar ka halwa     [Carrots, milk, sugar, ghee, cashews, raisins]
# 3            Ghevar  [Flour, ghee, kewra, milk, clarifiedbutter, su...
# 4       Gulab jamun  [Milkpowder, plainflour, bakingpowder, ghee, m...
# ..              ...                                                ...
# 250       Til Pitha             [Glutinousrice, blacksesameseeds, gur]
# 251         Bebinca  [Coconutmilk, eggyolks, clarifiedbutter, allpu...
# 252          Shufta  [Cottagecheese, drydates, driedrosepetals, pis...
# 253       Mawa Bati  [Milkpowder, dryfruits, arrowrootpowder, allpu...
# 254          Pinaca  [Brownrice, fennelseeds, gratedcoconut, blackp...
#
#            Diet  Prep_time  Cook_time Flavor_profile   Course  \
# ...

# %%
x=df['State']
x
# Out:
# 0          West Bengal
# 1            Rajasthan
# 2               Punjab
# 3            Rajasthan
# 4          West Bengal
#             ...
# 250              Assam
# 251                Goa
# 252    Jammu & Kashmir
# 253     Madhya Pradesh
# 254                Goa
# Name: State, Length: 255, dtype: object

# %%
# %matplotlib inline

# %%
sns.set_style("whitegrid")
sns.catplot(data=df, x="Region", y="State", hue="Diet", height=6, aspect=2)

# %%
sns.set_style("darkgrid")
sns.catplot(data=df, x="Region", y="State", hue="Flavor_profile", height=7, aspect=2)

# %%
sns.set_style("whitegrid")
sns.catplot(data=df, x="Region", y="State", hue="Course", height=6, aspect=2)

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10,5))
sns.barplot(x="Flavor_profile", y="Cook_time", hue="Diet", data=df)
# Out:
# <AxesSubplot:xlabel='Flavor_profile', ylabel='Cook_time'>

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10,5))
sns.barplot(x="Course", y="Cook_time", hue="Diet", data=df)
# Out:
# <AxesSubplot:xlabel='Course', ylabel='Cook_time'>

# %%
sns.set_context('notebook',font_scale=1.5)
plt.figure(figsize=(20,12))
sns.countplot(y=df.State,hue=df['Diet'])
plt.ylabel('States')
plt.xlabel('counts')
plt.title("Number of Food Items from Each State - Veg & Non-Veg")
plt.show()

# %%
pd.crosstab(df["Region"],df["Flavor_profile"]).plot(kind="line",figsize=(12,8),marker='o')
plt.title("Food Profile based on Region")
plt.show()

# %%
pd.crosstab(df["Region"],df["Course"]).plot(kind="bar",figsize=(10,8))
plt.title("Food course based on Region")
plt.show()

# %% [markdown]
# ### number of vegetarian and non-vegeterian dishes

# %%
# vegetarian / non-vegetarian dishes .

a = pd.DataFrame(df.groupby(by=['Diet']).count().Name)

plt.figure(figsize=(10, 7))

plt.barh(a.index, a.Name, label='count')

plt.xlabel("Diet")
plt.ylabel("Counts")
plt.title("Total counts of Vegetartian and Non-vegetarian dishes.")

plt.legend()
plt.show()

# %%
# Course types
a = pd.DataFrame(df.groupby(by = ['Course']).count().Name)
a.rename(columns = {'Name':'Count'}, inplace=True)
a.sort_values(by='Count', ascending=False, inplace=True)
plt.style.use("seaborn-whitegrid")

# visualization for the same
plt.figure(figsize=(14, 8))
sns.barplot(data=a, x=a.index, y='Count')

plt.title("Count of each course type")
plt.show()

# %%
north =df[df['Region']=='North']
pd.set_option('max_colwidth', 400)
north.head()
north[north['Time']!=0].sort_values('Time').head(5)
# Out:
#            Name                                                   Ingredients  \
# 252      Shufta  [Cottagecheese, drydates, driedrosepetals, pistachio, badam]
# 11        Lassi                                   [Yogurt, milk, nuts, sugar]
# 69   Aloo tikki           [Riceflour, potato, breadcrumbs, garammasala, salt]
# 17      Singori                                     [Khoa, coconut, moluleaf]
# 68    Aloo gobi     [Cauliflower, potato, garammasala, turmeric, curryleaves]
#
#            Diet  Prep_time  Cook_time Flavor_profile       Course  \
# 252  vegetarian          0          5          sweet      dessert
# 11   vegetarian          5         10          sweet      dessert
# 69   vegetarian          5         25          spicy  main course
# 17   vegetarian         10         25          sweet      dessert
# 68   vegetarian         10         25          spicy  main course
#
#                State Region  Time
# 252  Jammu & Kashmir  North     5
# ...

# %%
sns.kdeplot(x = 'Time', data = north[north.Flavor_profile!='0'],hue = 'Flavor_profile',shade=True)
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Density'>
